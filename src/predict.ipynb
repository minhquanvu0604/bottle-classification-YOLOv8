# %% [markdown]
# # Predict Images

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('/root/aifr/bottle-classification-YOLOv8/src/runs/classify/train/weights/best.pt')  # load a custom model

# Predict with the model
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /root/aifr/bottle-classification-YOLOv8/src/bus.jpg: 224x224 pin 0.48, hen 0.44, cro 0.08, 2.3ms
# Speed: 8.9ms preprocess, 2.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
import matplotlib.pyplot as plt


# Display results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im_rgb = im_array[..., ::-1]  # Convert BGR to RGB

    # Display the image using matplotlib
    plt.imshow(im_rgb)
    plt.axis('off')  # Hide axes
    plt.show()
